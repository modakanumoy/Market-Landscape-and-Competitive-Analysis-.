# %%
import matplotlib.pyplot as plt

# Data from the table
companies = ['Shaadi.com', 'BharatMatrimony', 'Jeevansathi']
revenue = [120, 300, 40]  # Revenue from Local Offices in crores
market_share = [25, 55, 20]  # Market Share in Local Markets in percentage
ebitda_margin = [16.7, 20, 12.5]  # EBITDA Margin in percentage

# Bar chart for Revenue from Local Offices
plt.figure(figsize=(10, 6))
plt.bar(companies, revenue, color=['blue', 'green', 'orange'])
plt.title('Revenue from Local Offices (in ₹ crore)')
plt.xlabel('Company')
plt.ylabel('Revenue (₹ crore)')
plt.show()

# Pie chart for Market Share in Local Markets
plt.figure(figsize=(8, 8))
plt.pie(market_share, labels=companies, autopct='%1.1f%%', colors=['blue', 'green', 'orange'])
plt.title('Market Share in Local Markets')
plt.show()

# Bar chart for EBITDA Margin from Local Operations
plt.figure(figsize=(10, 6))
plt.bar(companies, ebitda_margin, color=['blue', 'green', 'orange'])
plt.title('EBITDA Margin from Local Operations')
plt.xlabel('Company')
plt.ylabel('EBITDA Margin (%)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Extracting data from the image (simulated data loading)
data = {
    'Region': ['Andaman and Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 
               'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Goa', 'Gujarat', 'Haryana', 
               'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 
               'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 
               'New Delhi', 'Orissa', 'Pondicherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 
               'Tripura', 'Uttar Pradesh', 'Uttaranchal', 'West Bengal'],
    'Urban Pop 2010 (%)': [31.4, 33.8, 22.3, 11.5, 11.6, 97.3, 25.6, 9.9, 70.8, 74.6, 43.4, 28.7, 6.7, 30.9, 13.4, 
                           38.6, 47.7, 42.3, 54.4, 27.1, 45.6, 32.5, 22.3, 51.5, 26.3, 49.7, 14.3, 66.5, 35.1, 11.7, 
                           44.1, 38.1, 23.4, 22.3, 27.1, 30.7],
    'Urban Pop 2020 (%)': [35.7, 40.4, 27.5, 13.7, 15.3, 98.4, 32.5, 11.9, 58.5, 81.0, 48.3, 30.6, 8.9, 34.1, 15.2, 
                           43.8, 53.1, 48.6, 63.2, 32.1, 48.9, 37.0, 26.7, 57.4, 31.0, 55.9, 17.0, 74.9, 41.1, 13.2, 
                           48.0, 42.2, 29.8, 25.9, 32.2, 37.5],
    'Mean Years of Education 2010': [5.65, 4.81, 6.79, 6.28, 4.07, 4.17, 4.72, 9.19, 8.91, 6.60, 6.64, 6.20, 6.96, 
                                     5.87, 5.01, 7.08, 8.59, 6.48, 4.68, 7.10, 5.87, 6.84, 6.38, 6.03, 8.35, 4.79, 
                                     7.94, 4.82, 6.32, 6.82, 6.50, 5.60, 6.52, 4.99, 5.43, 5.35],
    'Mean Years of Education 2020': [7.06, 5.99, 7.93, 6.79, 5.47, 5.24, 6.89, 9.19, 9.91, 7.78, 6.94, 8.01, 6.87, 
                                     6.12, 6.31, 7.94, 9.09, 7.94, 5.91, 8.29, 8.26, 6.87, 8.11, 7.59, 9.59, 5.19, 
                                     9.42, 7.82, 8.74, 6.88, 8.18, 8.02, 6.73, 7.02, 6.24, 6.51],
    'Area Pop 2010 (millions)': [1.2, 97, 1.36, 31.0, 104.0, 1.03, 39.2, 0.3, 0.18, 1.98, 60.8, 23.6, 6.7, 12.5, 57.2, 
                                61.0, 35.8, 0.29, 0.06, 72.6, 113, 3.11, 2.3, 1.1, 1.9, 18.6, 41.9, 1.26, 24.4, 0.61, 
                                72.1, 35.1, 3.8, 201, 24.3, 93.2],
    'Area Pop 2020 (millions)': [1.30, 51.1, 1.8, 35.7, 35.2, 1.11, 32.5, 0.36, 1.98, 65.7, 76.8, 8.27, 6.97, 13.1, 
                                35.7, 82.7, 39.1, 0.16, 0.56, 64.8, 11.3, 3.57, 2.7, 1.3, 2.4, 20.4, 1.43, 8.97, 20.4, 
                                0.86, 78.8, 40.9, 4.04, 239, 11.6, 103],
    '% Change Urban Pop': [13.7, 19.5, 23.3, 19.1, 31.9, 1.1, 26.9, 20.2, -17.0, 8.5, 12.7, 6.6, 24.5, 10.4, 13.3, 
                           13.5, 11.3, 13.6, 16.1, 18.4, 7.2, 14.0, 19.7, 11.5, 17.9, 12.4, 18.9, 12.7, 14.8, 10.2, 
                           8.8, 10.7, 27.4, 16.1, 19.1, 22.2],
    '% Change Mean Years of Education': [24.5, 24.6, 16.8, 8.1, 34.5, 25.7, 46.0, 0.0, 11.2, 15.2, 4.5, 29.3, -1.3, 
                                         24.5, 26.1, 12.1, 5.8, 22.3, 26.3, 16.7, 41.3, 17.2, 27.0, 20.5, 14.8, 8.4, 
                                         18.6, 62.2, 38.4, 30.4, 24.4, 43.2, 10.3, 33.7, 14.9, 22.2],
    '% Change Area Pop': [10.7, -47.3, 32.4, 15.1, -66.1, 7.8, -17.0, 20.0, 1050.0, 3216.0, 18.2, -65.0, 4.0, 4.8, 
                         -37.5, 35.6, 9.2, -45.0, 833.3, -10.7, -10.5, 14.8, 17.4, 18.2, 26.3, 9.7, -65.0, 612.7, 
                         -19.2, 40.0, 9.3, 16.5, 6.3, 18.9, -52.3, 10.5]
}

df = pd.DataFrame(data)

# Correlation Analysis
correlation_matrix = df[['% Change Urban Pop', '% Change Mean Years of Education', '% Change Area Pop']].corr()

# Data Visualization
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title('Correlation Matrix of data')
